# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # plotting

# %%
img1=cv2.imread("Resources/lena_cut.png",0)

# %%
plt.imshow(img1)

# %% [markdown]
# # Arithmaic operation

# %%
img2=cv2.imread("Resources/Baboon.png",0)

# %%
plt.imshow(img2)

# %% [markdown]
# # addition

# %%
result=img1+img2

# %%
plt.imshow(result)

# %% [markdown]
# # substraction

# %%
result=img1-img2

# %%
plt.imshow(result)

# %%
result= img1*img2
plt.imshow(result)

# %%
result= img1/img2
plt.imshow(result)
# Out:
# C:\Users\sukadev\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\sukadev\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # blurring

# %%
img1=cv2.imread("Resources/Brain.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # zoom

# %%
img1=cv2.imread("Resources/lena_cut.png")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# # rotate

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %% [markdown]
# # translate

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img2,m,(height,width))
plt.imshow(dst)
